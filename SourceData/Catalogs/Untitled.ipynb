# %% [markdown]
# just some checks

# %%
import pandas as pd
import numpy as np

# %%
# !pwd
# Out:
# /home/jupyter-khickey/BA510/final-project-back-row-squad/SourceData/Catalogs

# %%
path = 'CourseCatalog2017_2018.csv'

df = pd.read_csv(path)

# %%
df.head()
# Out:
#   program_code   program_name catalog_id  \
# 0           AN  Asian Studies    AN 0301
# 1           AN  Asian Studies    AN 0310
# 2           BU       Business    BU 0211
# 3           BU       Business    BU 0220
# 4           BU       Business    BU 0311
#
#                                 course_title      credits           prereqs  \
# 0                          Independent Study  1-3 Credits               NaN
# 1                      Asian Studies Seminar    3 Credits               NaN
# 2              Legal Environment of Business    3 Credits  Junior standing.
# 3               Environmental Law and Policy    3 Credits               NaN
# 4  The Law of Contracts, Sales, and Property    3 Credits          BU 0211.
#
#   coreqs fees                                         attributes  \
# 0    NaN  NaN                                                NaN
# 1    NaN  NaN                                                NaN
# ...

# %%
df['program_code'].value_counts().count()
# Out:
# 83

# %%
path2 = './../Fall2018/courses.csv'

df2 = pd.read_csv(path2)
df2.head()
# Out:
#        term    crn catalog_id section credits  \
# 0  Fall2018  74177    AC 0011     01C   3.000
# 1  Fall2018  74194    AC 0011     02C   3.000
# 2  Fall2018  74195    AC 0011     03C   3.000
# 3  Fall2018  74196    AC 0011     04C   3.000
# 4  Fall2018  74197    AC 0011     05C   3.000
#
#                                   title  \
# 0  Introduction to Financial Accounting
# 1  Introduction to Financial Accounting
# 2  Introduction to Financial Accounting
# 3  Introduction to Financial Accounting
# 4  Introduction to Financial Accounting
#
#                                             meetings  \
# 0  [{'days': 'MR', 'times': '0330pm-0445pm', 'dat...
# 1  [{'days': 'TF', 'times': '0200pm-0315pm', 'dat...
# 2  [{'days': 'TF', 'times': '0330pm-0445pm', 'dat...
# 3  [{'days': 'MR', 'times': '0800am-0915am', 'dat...
# 4  [{'days': 'MR', 'times': '0930am-1045am', 'dat...
#
#                                    timecodes  primary_instructor  cap  act  \
# ...

# %%
df2['primary_instructor'].value_counts()
# Out:
# Nicole Elizabeth  Heller       54
# Sarah Jennie  Bollinger        14
# Sonya R.  Huber                14
# TBA                            12
# Brian G.  Walker               10
# Amalia I.  Rusu                 8
# Catherine J.  Andersen          8
# Laura A.  Conklin               8
# Terri L.  Germain-Williams      7
# Qin   Zhang                     7
# Michael Walden  Creane          7
# Marice E.  Rose                 7
# Michael A.  Camporiale          7
# Melissa A.  Roberto             7
# Gloria J.  Fazio                6
# Margaret A.  Wills              6
# Niall P.  Brennan               6
# Robert A.  Hardy                6
# Rose P.  Rodrigues              6
# Patrick A.  Kennedy             6
# John R.  Miecznikowski          6
# Aaron R.  Van Dyke              6
# Thomas Joseph  Murray           6
# David A.  Zera                  6
# Kelly Ann  Sullivan             6
# Diana R.  Mager                 6
# Nancy A.  Moriber               5
# ...
